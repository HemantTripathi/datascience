# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette("deep") # to avoid differences in color palette

# %%
# Please update seaborn to version 0.10.1 and matplotlib to version 0.3.2.2 using the below codes:

# !pip install -U seaborn==0.10.1
# Out:
# ...
#      |████████████████████████████████| 215 kB 3.5 MB/s eta 0:00:01
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.0
#     Uninstalling seaborn-0.10.0:
#       Successfully uninstalled seaborn-0.10.0
# ...

# %%
# !pip install -U matplotlib==3.2.2
# Out:
# ...
#      |████████████████████████████████| 12.5 MB 2.4 MB/s eta 0:00:01
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.1.3
#     Uninstalling matplotlib-3.1.3:
#       Successfully uninstalled matplotlib-3.1.3
# ...

# %%
# %matplotlib inline

# %%
np.random.seed(5)

# %%
x = np.random.normal(0, 3, size=10000)

# %%
sns.distplot(x,hist=False);

# %%
df= sns.load_dataset("iris");
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(df['sepal_width']);

# %%
tips = sns.load_dataset("tips");
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.heatmap(tips.corr(),annot=True, cmap='Blues');

# %%
sns.heatmap(tips.corr(),fmt='.2f');

# %%
sns.heatmap(tips.corr(),annot=True);

# %%
df= sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue="species");
